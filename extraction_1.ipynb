# %%
import json
import os
import math
import librosa

# %%
DATASET_PATH = "datasets/final_audio"
SAMPLE_RATE = 22050
TRACK_DURATION = 30  # seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

category_labelling_map = {
  "ambulance": 0,
  "police": 1,
  "fire-and-trucks": 2,
}

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
  data = {
    "category": [],
    "labels": [],
    "mfcc": []
  }

  samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
  num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

  for i, f in enumerate(os.listdir(dataset_path)):

    file_path = os.path.join(dataset_path, f)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

    # number of segments based on duration
    num_segments = int(len(signal) / SAMPLES_PER_TRACK) + 1

    category = f.split("_")[0]
    data["category"].append(category)

    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

    for d in range(num_segments):
      start = samples_per_segment * d
      finish = start + samples_per_segment

      # extract mfcc
      mfcc = librosa.feature.mfcc(y=signal[start:finish],
                                  sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft,
                                  hop_length=hop_length)
      mfcc = mfcc.T

      # store only mfcc feature with expected number of vectors
      if len(mfcc) == num_mfcc_vectors_per_segment:
        data["mfcc"].append(mfcc.tolist())
        data["labels"].append(category_labelling_map[category])
        print(f"segment:{d+1} -> {f}")

  with open(json_path, "w") as fp:
    json.dump(data, fp, indent=4)
  
  print(f"Saved {i} items to {json_path}")

# %%
# save_mfcc(DATASET_PATH, "data.json", num_segments=10)

# %%
# def save_mfcc2(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512):
#   data = {
#     "category": [],
#     "labels": [],
#     "mfcc": []
#   }
# 
#   for i, filename in enumerate(os.listdir(dataset_path)):
#     file_path = os.path.join(dataset_path, filename)
#     signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
# 
#     # duration = 1 / sr * len(signal)
#     # samples_per_tracks = sr * duration
#     
#     samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
#     num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)
#     
#     # number of segments based on duration
#     num_segments = int(len(signal) / SAMPLES_PER_TRACK) + 1
# 
#     category = filename.split("_")[0]
# 
#     for d in range(num_segments):
#       # start and finish sample for segment
#       start = int(SAMPLES_PER_TRACK * d)
#       finish = int(start + SAMPLES_PER_TRACK)
# 
#       # extract mfcc
#       mfcc = librosa.feature.mfcc(
#         y=signal[start:finish], sr=sample_rate,
#         n_mfcc=num_mfcc, n_fft=n_fft,
#         hop_length=hop_length)
#       mfcc = mfcc.T
# 
#       data["mfcc"].append(mfcc.tolist())
#       data["labels"].append(category_labelling_map[category]) # 
#       data["category"].append(category)
# 
#       print("{}, segment:{}".format(filename, d + 1))
# 
#   # save MFCCs to json file
#   with open(json_path, "w") as fp:
#     json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, "data2.json")
# Out:
# segment:1 -> ambulance_59.wav
# segment:1 -> police_17.wav
# segment:1 -> fire-and-trucks_33.wav
# segment:1 -> fire-and-trucks_36.wav
# segment:1 -> police_22.wav
# segment:1 -> police_5.wav
# segment:1 -> fire-and-trucks_8.wav
# segment:2 -> fire-and-trucks_8.wav
# segment:1 -> police_21.wav
# segment:1 -> ambulance_27.wav
# segment:1 -> fire-and-trucks_26.wav
# segment:1 -> ambulance_55.wav
# segment:1 -> fire-and-trucks_49.wav
# segment:1 -> ambulance_1.wav
# segment:1 -> ambulance_62.wav
# segment:1 -> fire-and-trucks_11.wav
# segment:1 -> police_32.wav
# segment:1 -> fire-and-trucks_17.wav
# segment:1 -> fire-and-trucks_55.wav
# segment:1 -> fire-and-trucks_46.wav
# segment:1 -> fire-and-trucks_4.wav
# segment:1 -> ambulance_54.wav
# segment:1 -> police_28.wav
# segment:1 -> police_23.wav
# segment:1 -> fire-and-trucks_41.wav
# segment:1 -> fire-and-trucks_10.wav
# segment:1 -> ambulance_57.wav
# segment:1 -> police_27.wav
# segment:1 -> ambulance_14.wav
# segment:1 -> police_2.wav
# segment:1 -> ambulance_22.wav
# segment:1 -> fire-and-trucks_56.wav
# segment:1 -> fire-and-trucks_15.wav
# segment:1 -> police_11.wav
# segment:1 -> ambulance_49.wav
# segment:1 -> ambulance_9.wav
# segment:1 -> ambulance_26.wav
# segment:1 -> fire-and-trucks_48.wav
# segment:1 -> ambulance_21.wav
# segment:1 -> ambulance_46.wav
# segment:1 -> ambulance_29.wav
# segment:1 -> ambulance_35.wav
# segment:1 -> police_1.wav
# segment:1 -> police_16.wav
# segment:1 -> fire-and-trucks_18.wav
# segment:2 -> fire-and-trucks_18.wav
# segment:1 -> fire-and-trucks_50.wav
# segment:1 -> ambulance_33.wav
# segment:1 -> ambulance_3.wav
# segment:1 -> police_3.wav
# segment:1 -> ambulance_18.wav
# segment:1 -> fire-and-trucks_29.wav
# segment:1 -> ambulance_12.wav
# segment:1 -> police_6.wav
# segment:1 -> ambulance_6.wav
# segment:1 -> fire-and-trucks_16.wav
# segment:1 -> police_30.wav
# segment:1 -> fire-and-trucks_39.wav
# segment:1 -> ambulance_68.wav
# segment:1 -> police_19.wav
# segment:1 -> fire-and-trucks_32.wav
# segment:1 -> fire-and-trucks_38.wav
# segment:1 -> police_10.wav
# segment:2 -> police_10.wav
# segment:1 -> fire-and-trucks_19.wav
# segment:1 -> ambulance_38.wav
# segment:1 -> fire-and-trucks_44.wav
# segment:2 -> fire-and-trucks_44.wav
# segment:1 -> ambulance_74.wav
# segment:1 -> ambulance_70.wav
# segment:2 -> ambulance_70.wav
# segment:1 -> ambulance_13.wav
# segment:1 -> police_24.wav
# segment:1 -> police_26.wav
# segment:1 -> fire-and-trucks_23.wav
# segment:1 -> ambulance_64.wav
# segment:2 -> ambulance_64.wav
# segment:3 -> ambulance_64.wav
# segment:4 -> ambulance_64.wav
# segment:5 -> ambulance_64.wav
# segment:1 -> fire-and-trucks_14.wav
# segment:1 -> ambulance_25.wav
# segment:2 -> ambulance_25.wav
# segment:1 -> ambulance_69.wav
# segment:1 -> fire-and-trucks_42.wav
# segment:1 -> fire-and-trucks_20.wav
# segment:1 -> ambulance_32.wav
# segment:1 -> police_15.wav
# segment:1 -> fire-and-trucks_9.wav
# segment:1 -> police_4.wav
# segment:1 -> fire-and-trucks_2.wav
# segment:2 -> fire-and-trucks_2.wav
# segment:1 -> fire-and-trucks_27.wav
# segment:1 -> police_20.wav
# segment:1 -> ambulance_76.wav
# segment:1 -> fire-and-trucks_28.wav
# segment:1 -> fire-and-trucks_30.wav
# segment:1 -> ambulance_4.wav
# segment:1 -> ambulance_53.wav
# segment:1 -> ambulance_48.wav
# segment:2 -> ambulance_48.wav
# segment:1 -> fire-and-trucks_1.wav
# segment:1 -> ambulance_47.wav
# segment:2 -> ambulance_47.wav
# segment:1 -> fire-and-trucks_7.wav
# segment:1 -> police_9.wav
# segment:1 -> fire-and-trucks_6.wav
# segment:1 -> fire-and-trucks_24.wav
# segment:1 -> police_18.wav
# segment:1 -> fire-and-trucks_37.wav
# segment:1 -> ambulance_36.wav
# segment:1 -> fire-and-trucks_22.wav
# segment:1 -> ambulance_16.wav
# segment:1 -> ambulance_19.wav
# segment:1 -> ambulance_41.wav
# segment:1 -> ambulance_28.wav
# segment:1 -> fire-and-trucks_25.wav
# segment:1 -> fire-and-trucks_3.wav
# segment:2 -> fire-and-trucks_3.wav
# segment:3 -> fire-and-trucks_3.wav
# segment:1 -> fire-and-trucks_40.wav
# segment:1 -> police_8.wav
# segment:2 -> police_8.wav
# segment:1 -> ambulance_30.wav
# segment:1 -> police_7.wav
# segment:1 -> ambulance_11.wav
# segment:1 -> ambulance_60.wav
# segment:1 -> ambulance_20.wav
# segment:2 -> ambulance_20.wav
# segment:1 -> ambulance_45.wav
# segment:1 -> police_13.wav
# segment:1 -> ambulance_56.wav
# segment:1 -> fire-and-trucks_13.wav
# segment:1 -> fire-and-trucks_45.wav
# segment:1 -> ambulance_72.wav
# segment:1 -> ambulance_8.wav
# segment:1 -> ambulance_44.wav
# segment:1 -> ambulance_24.wav
# segment:1 -> police_12.wav
# segment:1 -> police_14.wav
# segment:1 -> ambulance_40.wav
# segment:1 -> ambulance_17.wav
# segment:1 -> fire-and-trucks_54.wav
# segment:1 -> ambulance_5.wav
# segment:1 -> fire-and-trucks_51.wav
# segment:1 -> ambulance_42.wav
# segment:1 -> ambulance_52.wav
# segment:1 -> fire-and-trucks_31.wav
# segment:2 -> fire-and-trucks_31.wav
# segment:1 -> fire-and-trucks_43.wav
# segment:1 -> ambulance_39.wav
# segment:1 -> fire-and-trucks_5.wav
# segment:1 -> fire-and-trucks_34.wav
# segment:1 -> ambulance_34.wav
# segment:1 -> police_29.wav
# segment:1 -> ambulance_10.wav
# segment:1 -> police_25.wav
# segment:1 -> fire-and-trucks_21.wav
# segment:1 -> ambulance_77.wav
# segment:1 -> fire-and-trucks_35.wav
# Saved 164 items to data2.json
